# %% [markdown]
# # Check if timm is available on Kaggle

# %%
try:
    import timm
    print(f"✅ timm is available! Version: {timm.__version__}")
    print("You can use the original notebook with timm!")
except ImportError:
    print("❌ timm is not available")
    print("You need to enable internet to install it")
